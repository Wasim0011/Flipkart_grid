# %%
import spacy
from spacy.tokens import DocBin  # Import DocBin
import json
from tqdm import tqdm  # Import tqdm

# %% [markdown]
# ## Using annotator

# %%
nlp = spacy.blank("en")
db = DocBin()

# %%
with open('annotations_training.json', encoding='utf-8') as f:
    TRAIN_DATA = json.load(f)

# %%
with open('annotations_validation.json', encoding='utf-8') as f:
    VALID_DATA = json.load(f)

# %%
TRAIN_DATA
# Out:
# {'classes': ['PRODUCT_NAME',
#   'BRAND_NAME',
#   'WEIGHT',
#   'INGREDIENTS',
#   'NUTRITIONAL_INFO',
#   'FOOD_TYPE',
#   'PRICE',
#   'EXPIRY_DATE',
#   'MANUFACTURING_DATE',
#   'LIC_NUMBER',
#   'HELPLINE_NUMBER',
#   'OTHER_INFO'],
#  'annotations': [['protein more 15X than milk\r',
#    {'entities': [[0, 26, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['fortune\r', {'entities': [[0, 7, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['soya chunks\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['100% vegetarian\r', {'entities': [[0, 15, 'FOOD_TYPE']]}],
#   ['\r', {'entities': []}],
#   ['low fat\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   None,
#   ['\r', {'entities': []}],
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   ['fortune soya\r', {'entities': [[0, 12, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   None,
#   None,
#   ['steps to use nutritious fortune soya chunks\r',
#    {'entities': [[13, 23, 'NUTRITIONAL_INFO'], [24, 43, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['step one\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Protein content comparison\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Milk\r', {'entities': [[0, 4, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Wheat\r', {'entities': [[0, 5, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Egg\r', {'entities': [[0, 3, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Soya Chunks\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['3% 11%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['14%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['52%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['the\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['200\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serving Per Pack: Nutritional Information 501 Serve Size: 20g\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['343 68.6\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3.5%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['P\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['52.5 31.5 6.3\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10.5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['19.3%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['4.73 0.95\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['AS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0 0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Fe\r', {'entities': [[0, 2, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['0.8 02\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.2% 0.2%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SF\r', {'entities': [[0, 2, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['0.2\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.04\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.02 0004\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.2%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CN\r', {'entities': [[0, 2, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['0.1\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.1\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Song\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['108\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['216\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1.1%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Boil 1 cup of nutritious Fortune Soya Chunks in 4 cups of water and a pinch of salt for 5 minutes. Do not use salt for preparing sweet dishes.\r',
#    {'entities': [[25, 44, 'PRODUCT_NAME'],
#      [58, 63, 'PRODUCT_NAME'],
#      [79, 83, 'PRODUCT_NAME'],
#      [110, 114, 'PRODUCT_NAME'],
#      [129, 134, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['two\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Drain the water and rinse the chunks with fresh water.\r',
#    {'entities': [[10, 15, 'PRODUCT_NAME'], [42, 53, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['three\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['It 50 atesage and 2000\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['5DActed on tas\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['f54a\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['и прит угоду 2020 CMR\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['15X\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['low fat\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Fortune Soya Chunks is a great source of protein for vegetarians. It contains 15 times more protein than milk and is low fat free. It soaks water well, which makes Fortune Soya Chunks more delicious and easy to digest. It is a healthy food option for growing children and adults.\r',
#    {'entities': [[0, 19, 'PRODUCT_NAME'],
#      [25, 48, 'NUTRITIONAL_INFO'],
#      [53, 65, 'FOOD_TYPE'],
#      [78, 109, 'NUTRITIONAL_INFO'],
#      [117, 130, 'NUTRITIONAL_INFO'],
#      [140, 145, 'PRODUCT_NAME'],
#      [164, 183, 'PRODUCT_NAME'],
#      [189, 218, 'FOOD_TYPE']]}],
#   ['\r', {'entities': []}],
#   ['For manufacturing unit\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['address & FSSAI License\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['No., Please scan the OR code and see the bracketed portion of the batch no, printed\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lightly squeeze out the excess water before adding them to the recipe of your choice.\r',
#    {'entities': [[31, 36, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['FOR ANY SUGGESTIONS/COMPLAINTS, PLEASE CONTACT CUSTOMER CARE CELE AT CORPORATE OFFICE ADDRESS, TOLL-FREE NO: 1800 572 9999\r',
#    {'entities': [[109, 122, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['E-MAIL: care@adaniwilmar.in\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['KEEP IN A COOL, DRY AND HYGIENIC PLACE, AWAY FROM SUNLIGHT, STORE IN AIR-TIGHT CONTAINER AFTER OPENING THE PACK.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NO ARTIFICIAL COLOUR, NO ADDED PRESERVATIVE CONTAINS SOYA\r',
#    {'entities': [[0, 20, 'OTHER_INFO'], [22, 43, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Marketed by adani wilmar\r', {'entities': [[12, 24, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Corporate office\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['fssat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10013021000661\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Adani Wilmar Limited, Fortune House, Near Navrangpura Railway Crossing. Ahmedabad-380009, Gujarat, India\r',
#    {'entities': [[0, 20, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['INGREDIENT: Defatted Soy Flour\r',
#    {'entities': [[12, 30, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['NET WEIGHT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   [': 1 Kg\r', {'entities': [[2, 6, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['MRP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['linclusive of all taxes) :\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BATCH NO. :\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MFG. DATE:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['USE BY\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Adani Winiar Limited\r', {'entities': [[0, 20, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['8906007283120\r', {'entities': []}],
#   ['fortune\r', {'entities': [[0, 7, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['pure & hygienic sugar\r', {'entities': [[0, 21, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['sulphurless process\r', {'entities': [[0, 19, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['A premium crystals\r', {'entities': [[2, 18, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['fortunefoods.com\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['international standard\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Net Weight 500 g\r', {'entities': [[11, 16, 'WEIGHT']]}],
#   ['फ़ॉर्चुन\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['शुद्ध और हाइजीनिक चीनी\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['the teeth\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['myti pure when packet\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['The int DP tron\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['spertting white and ray to d\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['giene and p\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['STORAGE STORE IN COOL DRY AND HYGIENIC PLACE\r',
#    {'entities': [[8, 44, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['FOR ANY SUGGESTIONS/COMPLAINTS PLEASE CONTACT CUSTOMER CARE CELL\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['AT CORPORATE OFFICE ADDRESS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TOLL-FREE NO: 1800 572 9999 E-MAIL: care@adaniwilmar.in\r',
#    {'entities': [[14, 27, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['FSSC 22000\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['This toures that Fortune Sugar hygenic and safe tram any contamination when packed\r',
#    {'entities': [[17, 30, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Fortune Surashan\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['01302100\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MRP (inclusive of all taxes)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Use By:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Nutritional information\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['399.01 160\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['01 01\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['998 40\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.80%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['S\r', {'entities': [[0, 1, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['99.5 4.0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['01 01 0.15% 0.1\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.1 0.005%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Dietary\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['More Than\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['adani wilmar\r', {'entities': [[0, 12, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['0012043000430\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CONTENTS REFINED CRYSTAL SUGAR.Ingredients Sugarcane Juice NO ADDED FLAVOUR AND COLOUR\r',
#    {'entities': [[9, 42, 'PRODUCT_NAME'],
#      [43, 58, 'INGREDIENTS'],
#      [59, 86, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Fortune\r', {'entities': [[0, 7, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['FSSAI L1002001007437.1\r', {'entities': [[6, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Fortune pure & riggienic sugor\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['pure & hygienic sugur\r', {'entities': [[0, 15, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Net Weight 500 g\r', {'entities': [[11, 16, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['Batch No. Date of packaging & Use By: s\r', {'entities': []}],
#   ['X\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ERLAM OND\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['DRY FRUITS & MORE PREMIUM QUALITY\r',
#    {'entities': [[0, 10, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['RAISINS किशमिश\r', {'entities': [[0, 14, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['POWER BRAND\r', {'entities': [[0, 11, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Energy Booster\r', {'entities': [[0, 14, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Gluten Free\r', {'entities': [[0, 11, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['High Fiber\r', {'entities': [[0, 10, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Friendly\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['100% Natural\r', {'entities': [[0, 12, 'FOOD_TYPE']]}],
#   ['VEG HAKKA NOODLES\r', {'entities': [[0, 17, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Flipkart Supermart\r', {'entities': [[0, 18, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['READY TO COOK\r', {'entities': [[0, 13, 'FOOD_TYPE']]}],
#   ['\r', {'entities': []}],
#   ['400 g\r', {'entities': [[0, 5, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['Veg Hakka Noodles\r', {'entities': [[0, 17, 'PRODUCT_NAME']]}],
#   ['INSTRUCTIONS FOR USE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Bold Water in a large pan (You need about 1.25 It for every 200 gm of Hakka Noodies), Let the water bubble. Add the Flipkart Supermart veg Hakka Noodles to it. As the noodies are partially cooked, you would need to boil them for 21 min. Drain the noodles, spread on the Flat Surface, and toss the noodles in 1 sesspoon of oil to prevent them from sticking And make a dish of your choice.\r',
#    {'entities': [[5, 10, 'PRODUCT_NAME'], [116, 152, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Manufactured By: Original Foods, F10, Sarojini Nagar Industrial Area, Lucknow, Uttar Pradesh-226008, India.\r',
#    {'entities': [[17, 31, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['fssat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic No. 10017051002101\r', {'entities': [[8, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Marketed by Flipkart India Private Limited, Buildings Myssa Begonia & Clower, Embassy Tern Village, Outer Fing Roadt Devarabema anahalli Village enga 560100, Karnataka, India.\r',
#    {'entities': [[12, 42, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['fssai\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Le No. 10018043002295\r', {'entities': [[7, 21, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['STORE IN COOL, DRY & HIGIENICPLACE AWAY FROM DET SUNLIGHT Once Transfer the Contents into an airtight\r',
#    {'entities': [[0, 34, 'OTHER_INFO'], [35, 57, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['amaze cal calenие сите екидне\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1800-200-91198\r', {'entities': [[0, 14, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['supermart-feedback@flipkart.com\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['VEG HAKKA NOODLES\r', {'entities': [[0, 17, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Ingredients:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Refined Wheat Flour (Maida), lodized salt, Thickener (INS 412)\r',
#    {'entities': [[0, 27, 'INGREDIENTS'],
#      [29, 41, 'INGREDIENTS'],
#      [43, 62, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['PROPRIETARY FOOD-HAKKA NOODLES\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NUTRITIONAL INFORMATION (Approximate Values)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['00\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['A2000\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Pack Contains about 6 Serves (One Noodle Block is about 3 Serves)\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Allergen: Contains Wheat (Gluten).\r',
#    {'entities': [[19, 33, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['NET WEIGHT:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['400 g\r', {'entities': [[0, 5, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['MRP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Batch No.:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MFD\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Use By:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MABE ARRIB\r', {'entities': []}],
#   ['Del Monte Quality\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SINCE 1892\r', {'entities': [[0, 10, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['TOMATO KETCHUP\r', {'entities': [[0, 14, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['CLASSIC BLEND\r', {'entities': [[0, 13, 'OTHER_INFO']]}],
#   ['Del Monte Quality\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SINCE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1892\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TOMATO KETCHUP (CLASSIC BLEND)\r',
#    {'entities': [[0, 30, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Relish the Del Monte Pouch Pack!\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CONVENIENT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['UNBREAKABLE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SAFE & HYGIENIC\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INGREDIENTS:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Waiter, Tomato poste (25%), Sugar, lodland Salt, Thickeners 45 1422, INS 415), Acidity Regulator ONS 250, Splices and Condiments (Onion Powder, Garlic Powder and Mixed Spices), Sea Salt, Preservative INS 2111, Sweetener Stevia @ycoside (NS 960\r',
#    {'entities': [[0, 6, 'INGREDIENTS'],
#      [8, 20, 'INGREDIENTS'],
#      [28, 33, 'INGREDIENTS'],
#      [35, 47, 'INGREDIENTS'],
#      [49, 76, 'INGREDIENTS'],
#      [79, 104, 'INGREDIENTS'],
#      [106, 175, 'INGREDIENTS'],
#      [177, 185, 'INGREDIENTS'],
#      [187, 208, 'INGREDIENTS'],
#      [210, 243, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['This Contains Steviol Glycoside.\r',
#    {'entities': [[14, 31, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['CONTAIN NON-CALORIC SWEETENER\r', {'entities': [[0, 29, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Nutritional Information (Approx.)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Shop for us at shop.madewithdelmonte.in\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MARKETED AND MANUFACTURED BY:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Del Monte Foods Private Limited,\r',
#    {'entities': [[0, 31, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['C-2, First Floor, Plot No.-16, Udyog Vihar Phase-IV, Gurugram-122015, Haryana, India.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10012064000180\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['MANUFACTURED AT:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['No. 155/1, Kalukondapally Village, Krishnagiri Dist., Tamil Nadu 635 114, India\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Per 100 g approx. 10 pra size: 15g, No. of Servings: 50 (Approx)\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10012042000203 (E) Everest Beverages & Food Industries Private Limited Industrial Plot No: 19 & 20, Sector-8, Vedvyanpuri, Meerut, Uttar Pradesh-250103\r',
#    {'entities': [[9, 23, 'LIC_NUMBER'], [28, 79, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['0.8%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serving\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Energy\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['108 kcal\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Protein\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['09 27 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Carbohydrate\r', {'entities': [[0, 12, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Total Sugars\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['18.4 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Added Sugars\r', {'entities': [[0, 12, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['18 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['5.4% 0%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total Fat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['09\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Sodium\r', {'entities': [[0, 6, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['648 mg\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['4.9%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10018051002359\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['For any feedback or complamts, contact Consumer Care Executive at Del Monte Foods address, +91-124-4109436 feedback@delmonteloodsindia.in\r',
#    {'entities': [[66, 81, 'BRAND_NAME'], [91, 106, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['"Recommended Dietary Allowance of an average adult (2000 kcal\r',
#    {'entities': [[1, 61, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['NET QUANTITY:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['750 g\r', {'entities': [[0, 5, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['STORE IN A COOL, DRY AND HYGENIC PLACE\r',
#    {'entities': [[0, 38, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['DO NOT USE IF PACK IS SWOLLEN PUFFED LEAKING RECOMMENDED REFRIGERATION AFTER OPENING\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Use by For Date of Manufacture(M) No. (B) and "MRP? Inclusive of all y Date (U), Batch tapres\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['please see the pack\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8901246/005793\r', {'entities': []}],
#   ['X\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['KRBL\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['AGED To PERFECTION\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INDIA GATE\r', {'entities': [[0, 10, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['BASMATI RICE\r', {'entities': [[0, 12, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Everyday\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['net weight 5kg\r', {'entities': [[11, 14, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['INDIA GATE Everyday\r', {'entities': [[0, 19, 'BRAND_NAME']]}],
#   ['GMO\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['fssat LIC No.: 10018011005090\r', {'entities': [[15, 29, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['KRBLL\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ["WORLD'S LARGEST RICE MILLERS & BASWATI RICE EXPORTERS\r",
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Regd. Office: 5190, Lahori Gate, Delhi-110006, INDIA.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['203207\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['12714055000143.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['148024\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10012063000199. 29/15-29/16\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['11003613315002000139.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['258-259-260\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['110036\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['13315002000141.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['98/12\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['13110310815020000047.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INHA GATE INDIA GAZE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['For any comments/suggestions/complaints: Write to us at KRBL Limited, C-32, Sec. 62, Noida-201 301, Gautam Budh Nagar (UP) or call us at toll free mumber: 1800 1025290 E-mail: customercare@kblindia.com Follow us indiagatefoods:\r',
#    {'entities': [[155, 167, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['BEST BEFORE TWENTY FOUR MONTHS FROM PACKAG\r',
#    {'entities': [[0, 42, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['MRP (Incl. of all taxes)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PRODUCT OF INDRA\r', {'entities': [[0, 16, 'OTHER_INFO']]}],
#   ['FRESHNESS LOCK\r', {'entities': [[0, 14, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['TATA TEA\r', {'entities': [[0, 8, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Gold\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ONESS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Tulsi\r', {'entities': [[0, 5, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['NATU RALI INGREDIE IENTS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ginger\r', {'entities': [[0, 6, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['GOOD\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Brahmi\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Cardamom\r', {'entities': [[0, 8, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Mulethi\r', {'entities': [[0, 7, 'INGREDIENTS']]}],
#   ['TATA TEA Gold Care\r', {'entities': [[0, 18, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Goodness in every cup\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Det er\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Scan here for Buy Gold, Get Gold Offer\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BN\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['4. Ethnique code printed inside the pack to your pre\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET WEIGHT:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Use By\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1 kg\r', {'entities': [[0, 4, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['Date of Packaging\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MRP lock of all taxes\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ingredents Tea (96.15%), Natural Flavours and Natural Flavouring Substances Ginger, Cardamom, Tulsi, Multi\r',
#    {'entities': [[25, 75, 'OTHER_INFO'], [76, 106, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Mkt by. Tata Consumer Products Limited,\r',
#    {'entities': [[8, 38, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['TBshop Letroy Road, Kolkata, West\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Bengal-700 020. Lic. No.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10014031001025\r', {'entities': [[0, 14, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['FLAVOURED TEA\r', {'entities': [[0, 13, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['COMMON NAME\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PERCENTAGE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Milig by: For mig, unit details, read the letter at third place in batch code (B\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['and see below (T) Teward Warehousing Do. PVL L20 L Courtho Kolkata-700-088 10012031000059\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['OF FLAVOUR\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['2.03%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['GINGER CARDAMOM\r', {'entities': [[0, 15, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['1.15%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TULS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.41% 0.17%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LICORICE (MULETHI)\r', {'entities': [[0, 18, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['0.09%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['REGISTRATION NO: F-07/16\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10021032000004\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['(G) Amalgmited, Plot No. DL101, Gopalpur Industrial Park, Chamakhandi Chatrapur, Ganjam, Odisha-761\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CONSUMER CARE DETAILS: CUSTOMER CARE EXECUTIVE TATA CONSUMER PRODUCTS LTD, KIRLOSKAR BUSINESS PARK HEBBAL, BENGALURU-560 024, KARNATAKA.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TOLL FREE NUMBER: 1800 345 1720.\r',
#    {'entities': [[18, 31, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['EMAIL: care@tataconsumer.com\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Storage instructions: Once opened, transfer the contents into aarlight container and keep the lid tightly closed after each use for guidelines to dispose plastic for further recycle/reuse, please visit pwm tataconsumer.com\r',
#    {'entities': [[22, 127, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Images are for illustration pupae\r', {'entities': []}],
#   ['15% EXTRA\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ORYZANOL\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['100%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Fortified with Vitamins AOD\r',
#    {'entities': [[0, 27, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Super SARVOTTAM TM\r', {'entities': [[0, 18, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Physically Refined 100% Rice Bran Oil\r',
#    {'entities': [[0, 37, 'PRODUCT_NAME']]}],
#   ['सुपर\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['सर्वोत्तम\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Physically Refined 100% Rice Bran Oil\r',
#    {'entities': [[0, 37, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['NET CONTENT: 905 g\r', {'entities': [[13, 18, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['USE BY\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Fortified\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NOT TO BE SOLD LOOSE\r', {'entities': [[0, 20, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['PHYSICALLY REFINED RICE BRAN OIL\r',
#    {'entities': [[0, 32, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Nutritional Information" Servings per\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['89955 122:07 0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PBS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Contains natural anticadants and vitamins\r',
#    {'entities': [[0, 41, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['DATE OF PACKAGING\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['110\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Corporate\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['20.26\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['13.57\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['5.15\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['100\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['30\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['38\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['27 3.66\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1.75 0237\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['85%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Drying 1400\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['189.98\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1890 256.47 40.71\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['300 48.15 6.53\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['101.77\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1.25m 1.526\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['FREE FROM ARGEMONE OIL\r', {'entities': [[0, 22, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Recycle the Present, Save the Future\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MAX RETAIL PRICE INCLUSIVE OF ALL TAKES\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['080016791\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['For manufacturing unit address & FSSAI License No. Please scan the QR code and see the bracketed portion of the batch no. printed\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['FOR SUGGESTIONS COMPLAINTS CONTACT OUR CUSTOMER CARE EXECUTIVE AT THE REGD OFFICE OR CALL 1800-2700-701 EMAIL info@pbsoil\r',
#    {'entities': [[90, 103, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['BATCH NO\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['% Plot No. 1. Arjuni Industrial Estate Dhamtari (CG)-493773, INDIA, ASIA at www.sarvottamol.com\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PBS OIL INDUSTRIES PRIVATE LIMITED\r',
#    {'entities': [[0, 34, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['fssat Lic. No. 10012037000020\r', {'entities': [[15, 29, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['PER GRAM\r', {'entities': []}],
#   ['PARLE PLATINA\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['STIVE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PALE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Nutricrunch\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['DIGESTIVES\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['HIGH FIBRE\r', {'entities': [[0, 10, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['SOURCE OF IRON\r', {'entities': [[0, 14, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['VITAMINS & MINERALS\r', {'entities': [[0, 19, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['CONTAINS JOWAR RICH IN ANTIOXIDANTS & LOWER GI\r',
#    {'entities': [[0, 35, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['1kg PACK 10 PACKS\r', {'entities': [[0, 17, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['WITH MILLETS\r', {'entities': []}],
#   ['PARLE\r', {'entities': [[0, 5, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Happy Happy\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Choco-Chip Cookies\r', {'entities': [[0, 18, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['4\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['STAY FRESH PACKS INSIDE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Happy\r', {'entities': []}],
#   ['REST BEFORE SIX MONTHS FROM PACKAGING\r',
#    {'entities': [[0, 37, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['UC. No: 10012012000066\r', {'entities': [[8, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC. No: 10012032000038\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC No: 10012051000117\r', {'entities': [[8, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['MET WEIGHT: 396 g\r', {'entities': [[12, 17, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['11018028001188\r', {'entities': [[0, 14, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC a: 10012051000113\r', {'entities': [[7, 21, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['012042000028\r', {'entities': [[0, 12, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC No: 10012031000071\r', {'entities': [[8, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC. No: 100120-42000150\r', {'entities': [[9, 24, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC. No: 10020031003561\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC. No: 10014047000039\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC No.: 10012026000065\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['CONSUMER CARE CELL PARLE PRODUCTS PVT. LTD\r',
#    {'entities': [[19, 42, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['VILE PARLE EAST\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Email:cs@parle biz\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PHONE NO 122-4691 6025\r', {'entities': [[9, 22, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['LIC. Na 10012033000107\r', {'entities': [[8, 22, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['PARLE\r', {'entities': [[0, 5, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Happy Happy\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['PARLE\r', {'entities': [[0, 5, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Happy Happy\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['opy\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8-901719 122644\r', {'entities': []}],
#   ['Balanced Taste\r', {'entities': [[0, 14, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['TATA Salt\r', {'entities': [[0, 9, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['TATA Salt\r', {'entities': [[0, 9, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['OVER 40- TRUST\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Vacuum Evaporated lodised\r', {'entities': [[0, 25, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['SCAN ME\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['lodine Helps Mental Guarantee | Development*\r',
#    {'entities': [[0, 6, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Vacuum Evaporated lodmed Salt\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Images are for ustration purpose\r', {'entities': []}],
#   ['TATA Salt\r', {'entities': [[0, 9, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Ingredients: Edible Common Salt, Potassium lodate and Anticaking Agent (INS 536)\r',
#    {'entities': [[13, 31, 'INGREDIENTS'],
#      [33, 49, 'INGREDIENTS'],
#      [54, 79, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Nutritional Information (Typical values)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serve size: 1 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Servings per pack: 1000\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['% RDA Per serve\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Per 100 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Energy\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0 kcal\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Protein\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['0g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Carbohydrate\r', {'entities': [[0, 12, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['09\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total Sugars\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Added Sugars\r', {'entities': [[0, 12, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['09\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total Fat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['09\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Sodium\r', {'entities': [[0, 6, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['38000 mg\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['19\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['lodine\r', {'entities': [[0, 6, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['2 mg\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['14\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['nike solar salts Tata Salt is produced asing sacuum evaporation technology\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Tata Salt contains regalsite\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['lodine is required for normal growth, thyroid and brain function.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['*It is generally accepted that lodine helps in mental development nt of children\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CONSUMER CARE DETAILS: CUSTOMER CARE EXECUTIVE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TATA CONSUMER PRODUCTS LTD KIRLOSKAR BUSINESS PARK KIRLOSKAR HEBBAL BENGALURU-560024, KARNATAKA\r',
#    {'entities': [[0, 26, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['TOLL FREE NUMBER: 1800 345 1720 EMAIL: care@tataconsumer.com\r',
#    {'entities': [[18, 31, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['fssact\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['kt by: Tata Consumer Products Limited,\r',
#    {'entities': [[7, 37, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Bishop Lefroy Road, Kolkata, est Bengal-700020\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10014031001025\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Ig by: Tata Chemicals Limited, P. 0. Mithapur-361345\r',
#    {'entities': [[7, 29, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['strict-Devbhumi Dwarka, Gujarat Lic. No. 10012021000051\r',
#    {'entities': [[41, 55, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['packed by: For Packing unit address, please read letters of\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ch No. (B) and see below:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['D) R. K. Buffer, Godown No. 1-5, R. K. Warehouse, aru Gobind Singh Marg, Alamgir, District-Ludhiana anjab-141 116. Lic. fio. 10013063000252\r',
#    {'entities': [[125, 139, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['U) Pure Packaging Associates, Khasra No. 1784/579 Sewat No. 1208, Khata No. 345 & Khasara No. 1784/579 Sewat No. 1207, Khata No. 346, Kikri Morh Birpur, Irmandal Road, Birpur, District-Janmu, J&K-181 133\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['No. 10012061000164\r', {'entities': [[4, 18, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['(R) Mohan Enterprises, Godown No. 3, flear Shiv Mandir, ansi Road, District-Kanal, Haryana-132 001.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['No. 10014064000366\r', {'entities': [[4, 18, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['P) Mohan Enterprises, BJMS Logistics Park (Warehouse Bage Kheri Gurna, Tehsil-Rajpura, District-Patiala,\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['mjab-140 417. Lic. No. 10020063001747\r',
#    {'entities': [[23, 37, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['for Contest of ledine Deficiency orders\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['904043-901015\r', {'entities': [[0, 13, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['MRP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Jate of Packaging:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ise By:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ind of al tores\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET WEIGHT: 1 kg\r', {'entities': [[12, 16, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['KEEP IN A COOL AND DRI PLACE STORE AWAY FROM DIRECT HEAT\r',
#    {'entities': [[0, 56, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['SUNLIGHT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PET-P\r', {'entities': []}],
#   ['डाबर\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['च्यवनप्राश\r', {'entities': [[0, 10, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['3x इम्यूनिटी एक्शन\r', {'entities': [[0, 18, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['क्लिनिकली प्रमाणित\r', {'entities': [[0, 18, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['라고 पीमारियों से\r', {'entities': []}],
#   ['115.00\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['(₹0.46/9)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BM10891\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['01/2024\r', {'entities': [[0, 7, 'MANUFACTURING_DATE']]}],
#   ['\r', {'entities': []}],
#   ['122026\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ch\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET QUANTITY: 250g\r', {'entities': [[14, 18, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['Mid. in d. in India by: DABUR INDIA LIMITED Village Manakpur, Tehsil Baddi, Distt Solan (H.P.)-174101, M.L. HP-183-AT Regd. Office & Consumer Cell: 8/3, Asaf Ali Road, New Delhi-110002 E-Mail: daburcares@dabur.com\r',
#    {'entities': [[24, 43, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Toll Free: 1800-103-1644 Suitable for all age groups and in af seasons\r',
#    {'entities': [[11, 24, 'HELPLINE_NUMBER'], [25, 52, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['OAL FREE 1800-103-1644\r', {'entities': [[9, 22, 'HELPLINE_NUMBER']]}],
#   ['OPEN ZIP LOCK ACUTANE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['EASY TO STORE FACEPACK ZIPLOCICKEEPS CONTRATS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BIKANO\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Aloo Bhujia\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Crunchy Spicy Noodles of Potato & Chickpea Flour\r',
#    {'entities': [[0, 48, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Crunchy\r', {'entities': [[0, 7, 'OTHER_INFO']]}],
#   ['OPEN ZIP LOCK AND CUT AHEN MEMBRANE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BASY TO STORE FAME PACK\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BIKANO\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Thy Derange of freidisinal Indian Ram\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Refined Palmeden\r', {'entities': [[0, 16, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Chill Powder\r', {'entities': [[0, 12, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Aloo Bhujia\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Dt Refred Riban Refined Gittanseed D\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Uried Mint Dried Mango Powder, Camin Powder\r',
#    {'entities': [[0, 29, 'INGREDIENTS'], [31, 43, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Powder Green Chilli Powder utmeg Powdered Powder Cam\r',
#    {'entities': [[7, 26, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Flour lodund Salt, Sugar Sucrose), Onion Powder, Garlic Powder,\r',
#    {'entities': [[19, 32, 'INGREDIENTS'],
#      [35, 47, 'INGREDIENTS'],
#      [49, 62, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['Added Ravour Natural and Nature Mentical Flavouring\r',
#    {'entities': [[0, 51, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Poked Dew Math Bean)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Sesame, Nuts, Soy and Gats,\r', {'entities': [[0, 26, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['ABAND DIRECT SUNLIGHT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ARTIGHT CONTAINER\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['natee first two characters of Batch No. and see below\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Foods Pvt. Ltd\r', {'entities': [[0, 14, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['NUTRITIONAL INFORMATION\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serving\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Size: 30g Servings Per Package 33 app Per 100g %\r',
#    {'entities': [[6, 9, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['RDA Per Serve\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Nutrition Facts\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serving Size\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Calories\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total Fal\r', {'entities': []}],
#   ...]}

# %%
VALID_DATA
# Out:
# {'classes': ['PRODUCT_NAME',
#   'BRAND_NAME',
#   'WEIGHT',
#   'INGREDIENTS',
#   'NUTRITIONAL_INFO',
#   'FOOD_TYPE',
#   'PRICE',
#   'EXPIRY_DATE',
#   'MANUFACTURING_DATE',
#   'LIC_NUMBER',
#   'HELPLINE_NUMBER',
#   'OTHER_INFO'],
#  'annotations': [None,
#   ['\r', {'entities': []}],
#   ['BALAJI\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['BALAJI\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['WAFERS\r', {'entities': [[0, 6, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Khatta Mitha Mix\r', {'entities': [[0, 16, 'PRODUCT_NAME']]}],
#   ['BALAR\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['EMEGHT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INS PEANUTS MILK POWDER\r', {'entities': [[4, 23, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['PER 100g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['568 Kral\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['DAILY VALUE OF RDA PER 300\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['95\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['49.79\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['88g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['55g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1169\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['32.4g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['75%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['B7g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['19%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['<<019\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['<<1%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['<1mg\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['371 mg\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['6%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['DAMOUNT ATOROING TO "RECOMMENDED DIETARY 2000KCAL DET) AS PER FSSR (LABELLING & DISPLAY)\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LOFALL TAXES)-\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['M\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['250g\r', {'entities': [[0, 4, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['40.00\r', {'entities': [[0, 5, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['CE:₹0.16 PER g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['USC4GA\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0/08/\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['29/11/24\r', {'entities': [[0, 8, 'MANUFACTURING_DATE']]}],
#   ['\r', {'entities': []}],
#   ['DATE:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET SUNLIGHT & HEAT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8906010-503697\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SERVING SIZE: 300\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BALAJI\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['WAFERS\r', {'entities': [[0, 6, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Khatta Mitha Mix\r', {'entities': [[0, 16, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['MANUFACTURED BY: BALAJI WAFERS PRIVATE LIMITEL REGO, OP\r',
#    {'entities': [[17, 46, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['NO.19 VAJDI (VAD), KALAWAD ROAD\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LODHIKA, DIST. RAJKOT-360021, GUJARAT-N\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Issat LICENSE NO. 10012021000039 2: SURVEY NO 360 SHAM\r',
#    {'entities': [[18, 32, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['NO. 48, NEAR DUNGARI VILLAGE TA DIST VALSAD-PR\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ssat LICENSE NO. 10012021000037. 13: PLOT NO 23,465\r',
#    {'entities': [[17, 32, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['INDUSTRIAL AREA, RAU PITHAMPUR LINK ROAD, TER\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MADHYA PRADESH INDIA fat LICENSE NO 10060250005\r',
#    {'entities': [[36, 47, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['TO 40, PHASE 2, UPSIDC, TEH, SANDILA, DIST HARDD-ZA\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INDIA fat LICENSE NO. 12723999000174. FOR MANUFACTURING\r',
#    {'entities': [[22, 37, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Issaf LICENSE NO, SEE FIRST TWO CHARACTERS OF BATHING\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Website: www.balajiwafers.com\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['IF YOU FIND ANY FAULT REGARDING QUALITY OF ANT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['IN THIS PACKET, PLEASE INFORM US, WE WILL REAAE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['FOR FEEDBACK, COMPLAINTS AND QUERIES RESER\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['REGISTERED OFFICE ADDRESS CALL OUR COMME +91-7069014141 ON AN WORKING D TO 6:00PM OR E-MAIL US AT: CONT\r',
#    {'entities': [[41, 55, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['DO NOT BUY THE PACK IF FOUND DAMAGEDIREN\r',
#    {'entities': [[0, 40, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['fssat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LIC. NO. 10012021000039\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['FOL\r', {'entities': []}],
#   ['REAL\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ONLY 5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Bites! (R\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Masala Papdi\r', {'entities': [[0, 12, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['suggested servings\r', {'entities': []}],
#   ['REAL Bites!\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Papdr\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Information\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PER 100g % Daily Value of RDA Per 30 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['563.7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['37.8\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['17%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Sahelhed Fat g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['16.5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['22%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.1\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Cholesterol ing\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['849.8\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['13%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Carbohydrate g\r', {'entities': [[0, 12, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['40.0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total supar g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1.5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['which added sugar g\r', {'entities': [[6, 17, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['0%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['15.8\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['UPPROXIMATE VALUES ELINE DAILY AMOUNT ACCORDING TO COMMENDED DIETARY ALLOWANCE FOR MERAGE ADULT PER DAY\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Masala Papdi\r', {'entities': [[0, 12, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['INGREDIENTS\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Gram Flour (Besan) (58.7%), Edible Vegeta (Palmolein), Spices & Condiments Mix Red (Lal Mirchi), Edible Black Salt, Turmeric Pow Cumin Powder)-(6.0%), Edible lodised Salt Dried Mango Powder (Amchur), Asafoetida Agent (Sodium Bicarbonate)- (E/INS-5000\r',
#    {'entities': [[0, 25, 'INGREDIENTS'],
#      [28, 53, 'INGREDIENTS'],
#      [55, 95, 'INGREDIENTS'],
#      [97, 114, 'INGREDIENTS'],
#      [116, 149, 'INGREDIENTS'],
#      [151, 170, 'INGREDIENTS'],
#      [171, 198, 'INGREDIENTS'],
#      [200, 237, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['CONTAINS PERMITTED NATURAL COLOUR ENS\r',
#    {'entities': [[0, 33, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['ALLERGY ADVICE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Manufactured in a facility that may process soy pr\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['solid, peanuts, tree nuts, nuts, sesame seeds\r',
#    {'entities': [[0, 45, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['KCAL DIET) AS PER FSSR (LABELLING & DISPLAY) 2020.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ARVING PER PACKAGE: 1 SERVING SIZE: 30 g\r',
#    {'entities': [[36, 40, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['TRISPRIETARY FOG\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Hacks & Savouries Products\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['"Real Bites" is only Trademark and does not represent its the nature."\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Marachuted by\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LAXMI SHACKS PVT. LTD.\r', {'entities': [[0, 21, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['NH.NO 8, Virage Tondel, To Nadiad. Dist: Kheda, G-327230, INDIA 80-20-000-05-AMACL3151N-22\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8906019 56059\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['V\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['For MRP (Incl. of all taxes), see the panell belt\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MAX RETAIL PRICE ₹5.00 (Rs. 0.23 per g)\r',
#    {'entities': [[17, 39, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['Mfg Dt.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['follow us on\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['f\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET WT. 228\r', {'entities': [[8, 11, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['B. NO\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ea\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['54MC\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['18SEP24\r', {'entities': [[0, 7, 'MANUFACTURING_DATE']]}],
#   ['\r', {'entities': []}],
#   ['153425\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['04:22\r', {'entities': []}],
#   ['250g\r', {'entities': [[0, 4, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['DALMIA GOLD\r', {'entities': [[0, 11, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Big Brand\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['कड़क दानेदार चाय\r', {'entities': [[0, 16, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['A DALMIA PRODUCT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['TM\r', {'entities': []}],
#   ['WUTRITIONAL INFORMATION\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Prea\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3843\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['60.00\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Traces\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Tatat Far\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['922\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Traces\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8908000279552\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NIET WT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['250g\r', {'entities': [[0, 4, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['WRP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['95.00\r', {'entities': [[0, 5, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['Ind of at laxes)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BATCH NO\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['JAN-2\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['BEST GEFORE 12 MONTHS FRO\r', {'entities': [[0, 21, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['THE DATE OF PACKAGING\r', {'entities': []}],
#   ['Kissan Pizza & Pasta sauce is now\r',
#    {'entities': [[0, 26, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['kissan Pizza & Pasta\r', {'entities': [[0, 6, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['SAUCT\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SINCE 1838\r', {'entities': [[0, 10, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Knorr\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PIZZA & PASTA SAUCE\r', {'entities': [[0, 19, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Our Promise\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['With 100% Real Vegetables\r', {'entities': [[0, 25, 'FOOD_TYPE']]}],
#   ['\r', {'entities': []}],
#   ['No dide Colours\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Per Serve\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['(509)\r', {'entities': []}],
#   ['Cooking Instructions\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Veggie Penne Pasta\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ingredients: 2% Tbsp (50 g) Knorr Pizza & Pasta Sauce, 1 cup (50 g) boiled penne pasto, 1% cup (150 g) chopped vegetables (bell peppers, broccoli, baby corn, carrot, zucchini), 1 Tbsp Glee oil.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Per Senre: 50 g (3 Tbsp) Number of serves per pack - Approx. 4\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1. Het pan, add oil and sau Vegetables for 3 to 4nutes.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['2. Add boiled pasta and toss for 1 minute.\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3. Add Knorr Pizza & Pasta Sauce, mix well and serve hot!\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['USE TO COOK. SPREAD. DIP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Nutrition Information [Typical Values)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['product Per 100 g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Per Serve\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['% RDA/ Serve\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Energ.col)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['83\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['42\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['2%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Protei\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1.4\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Carbohate (g) Total Sars (g)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['14\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10.7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['5.3\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Added Sugars (g)\r', {'entities': [[0, 12, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3.5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['7%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Detary Fibre (0)\r', {'entities': [[0, 12, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['1\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.5\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total F\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['24\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['12\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['2%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Setrated Fo\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.4\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.2\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['<1%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ans Fat\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.02\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0.01\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['<1%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Cholential (mg)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['0\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['dun (ng)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['909\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['454\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['23%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Kissan now Knorr\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Pasta sauce Pasta sauce is\r', {'entities': [[0, 11, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['CULINARY SAUCE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['INGREDIENTS: Water, Veges (Crushed Tomato 25%, Diced Toma Onion-3.5% and Garlic Paste 5%), Sugar, Tomo 20%, Chopped lodised Salt, Soyabean Oil, Stab-E1422, E415, Acidity Regulator-E260, Hime (Oregano and Basil-0.12%), White Pepper Powder, Preservative-6211, Natural Flavouring Substance, May contain traces of Gluten, Soya, Milk and Nuts.\r',
#    {'entities': [[13, 18, 'INGREDIENTS'],
#      [20, 88, 'INGREDIENTS'],
#      [91, 96, 'INGREDIENTS'],
#      [98, 106, 'INGREDIENTS'],
#      [108, 128, 'INGREDIENTS'],
#      [130, 142, 'INGREDIENTS'],
#      [162, 184, 'INGREDIENTS'],
#      [186, 216, 'INGREDIENTS'],
#      [218, 237, 'INGREDIENTS'],
#      [239, 256, 'INGREDIENTS'],
#      [258, 286, 'INGREDIENTS'],
#      [288, 316, 'INGREDIENTS'],
#      [318, 322, 'INGREDIENTS'],
#      [324, 337, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ["adult's Recommended Dietary Allowance (2000 kcal diet)\r",
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['NET WEIGHT: 200 g\r', {'entities': [[12, 17, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['265/\r', {'entities': [[0, 4, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['10.33/g\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10/07/24\r', {'entities': [[0, 8, 'MANUFACTURING_DATE']]}],
#   ['\r', {'entities': []}],
#   ['09/07/25\r', {'entities': [[0, 8, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['D0857 00:18\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MKTD. BY: Lic Unilever House, B. D. Sawant Mory, Chakala Mumbai- User Hindustan Unilever Ltd. (HUL). Andheri (E 1-400 099, Maharashtra HUL 2020\r',
#    {'entities': [[10, 28, 'BRAND_NAME'], [70, 99, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['FOR MFR. & MFG. UNIT ADDRESS READ THE FIRST CHARACTER OF THE BATCH No. AND SEE BELOW MFG. BY: (S) SYMEGA Food Ingredients Ltd., Synthite Taste Park, No. XI 3126, Pancode, Near Kolenchery, Emakulam District, Kerala FSSAI Lic. No. 10012041000078. (D) 682 310, India Sahyadri Farms Post Harvest Care Limited Gat No:314/1, 314/2/ Alp: Mohadi, Taluka: Dindori, Nashik, Maharashtra- 422 207, India. FSSAI Lic. No. 11522999000129. Stare in a cool, dry & hygienic place away from direct inlight. After opening, keep refrigerated (3-10°C) and use within 6 months or use by date whichever is canier. Do not buy if the pack is\r',
#    {'entities': [[229, 244, 'LIC_NUMBER'],
#      [408, 423, 'LIC_NUMBER'],
#      [534, 589, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['tom/punctured/bloated/damaged. HUL Regn. No. BO-13-000-07-AAACH1004N-22\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Knorr is a registered trademark of knorr- Naehrmittel AG., Switzerland, produced in India by Hindustan Unilever Ltd. Licensed User.\r',
#    {'entities': [[93, 116, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['LEVERCARE QUERY/FEEDBACK TOLL FREE: 1800-10-22-221 PO BOX 14760, MUMBAI 400 999 LEVER.CARE@UNILEVER.COM\r',
#    {'entities': [[36, 50, 'HELPLINE_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['fssai\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['OTHER\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Lic. No. 10013022001897,\r', {'entities': [[9, 23, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Unillev\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8901030 919305\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['MRP (INCL. OF ALL TAXES), USP, PKD., USE BY & BATCH No.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['See seal area\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Preg Man Mid By Muhamali India Ltd, Khopol PR-22\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['6970356\r', {'entities': []}],
#   ['FREE GET ONE\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['alable baglor altimate freshness\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['RICH DETARY FIBER\r', {'entities': [[0, 17, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['LION\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['RICH NATURE SUGAR A\r', {'entities': [[0, 17, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['ZERD PHOLESTEROL A\r', {'entities': [[0, 16, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Arabian DATES D\r', {'entities': [[0, 13, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['100% कुवती अजूर। बीज को कती है।\r', {'entities': []}],
#   ['Arabian LION DATES\r', {'entities': [[0, 18, 'PRODUCT_NAME']]}],
#   ['\r', {'entities': []}],
#   ['Imported by:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LION DATES IMPEX PVT LTD., No. 4A/3. Cauvery Road, Inchy-620 002, Tamil Nadu, India.\r',
#    {'entities': [[0, 25, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['fssai Lic. No. 10012042000634\r', {'entities': [[15, 29, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['Country of Origin: Iraq\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Packed & Marketed by:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['LION DATES IMPEX PVT LTD., No. 27/3, Cauvery Road, Inchy-620002, Tamil Nadu, India.\r',
#    {'entities': [[0, 25, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['fssai Lic.No. 10013042001080\r', {'entities': [[14, 28, 'LIC_NUMBER']]}],
#   ['\r', {'entities': []}],
#   ['ir laggestions and Complaints, Contact our Customer Care Executive anthe Lastumer Care Cell\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['1-800-4252649 (Toll-free) LION DATES IMPEX PVT LTD., PO Box No.: 3313, 40. Nunganbokkam, Chennai-600 034, Tamil Nadu. mait astomercare@liondates.com\r',
#    {'entities': [[0, 13, 'HELPLINE_NUMBER'], [26, 51, 'BRAND_NAME']]}],
#   ['\r', {'entities': []}],
#   ['EUANTITY:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['SALE PRICE:\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['PACKAGING\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['250 g\r', {'entities': [[0, 5, 'WEIGHT']]}],
#   ['\r', {'entities': []}],
#   ['Scan here t Divy special valty\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['100% Natural dates straight from the desert farms. Recommended to remove the seed and wash the dates before eating.\r',
#    {'entities': [[0, 50, 'OTHER_INFO']]}],
#   ['\r', {'entities': []}],
#   ['அரேபிய தோட்டங்களிலிருந்து வரும் 100% இயற்கையான பேரிச்சம் பழம் வதற்கு முன் கொட்டையை நீக்கியிட்டு கழுவி சாப்பிடவும் சாப்பிடுவதற்கு மு\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ఆరేబియా తోటలనుండి వచ్చే 100% సహజమైన ఖర్జూరాలు, తినడానికి ముందు గింజలను తీసివేసి, కడిగి తినడం ఆరోగ్యకరం.\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ededata Saturn 100% and ಖರ್ಜೂರಗಳು ತಿನ್ನುವುದಕ್ಕೆ ಮುಂಚೆ ಬೀಜಗಳನ್ನು ತೆಗೆದು ಹಾಕಿ ತೊಳೆದು ತಿನ್ನುವುದು ಆರೋಗ್ಯಕರ\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['सीधे अरेबिया के माईन से आनेवा 100% कुदरती खजूर खाने खजूर को धोकर बीज निकाrिe खाना स्वास्थ्य के लिए अप\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['അറേബിയൻ തോട്ടങ്ങളിൽ നിന്ന് വരുന്ന 100% പ്രകൃതിദത്തമായ ഈന്തപ്പഴം കഴിക്കുന്നതിന് മു വിത്ത് മാറ്റി കഴുകി കഴിക്കുന്നത് ആനുകാലാണ്\r',
#    {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Ingredient: Wet Dates\r', {'entities': [[12, 21, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['NUTRITIONAL INFORMATION per serving (\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['10 Servings per pack\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Serving Size\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['25 per serving\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Energy (kcal)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['8054枚\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Protein (g)\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['05\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['15\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Carbohydrate (0)\r', {'entities': [[0, 12, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['194\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['70%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Rs.115.00 (Inclusive of all taxes) Rs.0.46 per g 26.07.2024\r',
#    {'entities': [[0, 59, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['of Which Sugar pl\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['174 635\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Added Sugar (g)\r', {'entities': [[0, 11, 'INGREDIENTS']]}],
#   ['\r', {'entities': []}],
#   ['M\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Total Fat (g)\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['01\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['615\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['18 64% 0.04%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Dietary Fiber (g)\r', {'entities': [[0, 13, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['25.01.2025\r', {'entities': [[0, 10, 'EXPIRY_DATE']]}],
#   ['\r', {'entities': []}],
#   ['SD/C 034\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['04\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Sodium (mg)\r', {'entities': [[0, 6, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['167.7\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['3.6% 122 13%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Potassium (mg)\r', {'entities': [[0, 9, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['Calcium (mg)\r', {'entities': [[0, 7, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['09 3.3%\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['hydry pouch\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['An HACCP &\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['ISO 22000: 2018\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Certified Company\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['د\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['OTHER\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['is ₹15/kg-\r', {'entities': [[3, 10, 'PRICE']]}],
#   ['\r', {'entities': []}],
#   ['KEEP\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['YOUR CITY\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['CLEAN\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['Iron (mg)\r', {'entities': [[0, 4, 'NUTRITIONAL_INFO']]}],
#   ['\r', {'entities': []}],
#   ['"Percent RDA Your daty wance Calorie nood\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['"APPROOMAR WALUES\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['\r', {'entities': []}],
#   ['', {'entities': []}]]}

# %% [markdown]
# ## Generating Training Data in spacy format

# %%
for entry in tqdm(TRAIN_DATA['annotations']):
    if entry is None:
        print("Skipping NoneType entry")
        continue
    try:
        text, annot = entry  # Unpack the entry
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot['entities']:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    except ValueError as e:
        print(f"Skipping malformed entry: {entry}, error: {e}")
        
db.to_disk("training_data.spacy")  # Save the DocBin object
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 3390/3390 [00:00<00:00, 13243.27it/s]
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping NoneType entry
# Skipping entity

# %% [markdown]
# ## Generating Validation Data in spacy format

# %%
for entry in tqdm(VALID_DATA['annotations']):
    if entry is None:
        print("Skipping NoneType entry")
        continue
    try:
        text, annot = entry  # Unpack the entry
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot['entities']:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print("Skipping entity")
            else:
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    except ValueError as e:
        print(f"Skipping malformed entry: {entry}, error: {e}")
        
db.to_disk("validation_data.spacy")  # Save the DocBin object
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 603/603 [00:00<00:00, 15544.96it/s]
# Skipping NoneType entry

# %% [markdown]
# ## Custom NER Model Training

# %%
! python -m spacy init config config.cfg --lang en --pipeline ner --optimize efficiency
# Out:
# [!] To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# [i] Generated config template specific for your use case
# - Language: en
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# [+] Auto-filled config with all values
# [+] Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
! python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./validation_data.spacy --verbose
# Out:
# [i] Saving to output directory: .
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00      1.96    0.00    0.00    0.00    0.00
#   1     200        382.88   3109.80   27.72   32.03   24.43    0.28
#   3     400        438.75   2138.82   53.12   59.24   48.15    0.53
#   6     600       1265.57   2127.82   74.97   77.24   72.82    0.75
#   9     800       1024.77   1496.93   83.89   86.66   81.29    0.84
#  12    1000        676.26   1038.08   88.78   91.41   86.29    0.89
#  17    1200        560.95    771.24   87.90   89.70   86.17    0.88
#  23    1400        671.04    682.65   91.04   91.87   90.23    0.91
#  29    1600        403.73    556.72   91.40   92.87   89.99    0.91
#  38    1800        924.44    592.78   90.89   92.05   89.75    0.91
#  48    2000        330.67    578.12   90.82   92.04   89.63    0.91
#  61    2200        407.68    647.61   91.10   91.98   90.23    0.91
#  76    2400        425.14    718.28   90.74   92.14   89.39    0.91
#  91    2600        455.41    687.91   91.49   92.67   90.35    0.91
# 107    2800        297.38    666.98   90.78   91.83   89.75    0.91
# 122    3000        292.90    664.09   91.28   92.74   89.87    0.91
# 137    3200        281.42    595.54   91.59   93.00   90.23    0.92
# 153    3400        173.14    563.59   91.49   93.31   89.75    0.91
# 168    3600        192.43    562.49   92.32   94.51   90.23    0.92
# 184    3800        291.35    569.69   92.50   94.75   90.35    0.92
# 199    4000        305.51    586.21   91.92   94.47   89.51    0.92
# 214    4200        249.96    587.24   91.40   92.87   89.99    0.91
# 230    4400        282.99    577.20   91.38   92.44   90.35    0.91
# 245    4600        146.11    498.44   91.87   94.35   89.51    0.92
# 260    4800        191.45    523.36   91.70   93.23   90.23    0.92
# 276    5000        160.20    496.70   91.74   93.56   89.99    0.92
# 291    5200        228.60    515.03   92.38   95.31   89.63    0.92
# 307    5400        183.11    542.65   92.09   94.82   89.51    0.92
# [+] Saved pipeline to output directory
# model-last
# [2024-10-19 19:39:55,121] [DEBUG] Config overrides from CLI: ['paths.train', 'paths.dev']
# [2024-10-19 19:39:55,298] [INFO] Set up nlp object from config
# [2024-10-19 19:39:55,299] [DEBUG] Loading corpus from path: validation_data.spacy
# [2024-10-19 19:39:55,299] [DEBUG] Loading corpus from path: training_data.spacy
# [2024-10-19 19:39:55,299] [INFO] Pipeline: ['tok2vec', 'ner']
# [2024-10-19 19:39:55,309] [INFO] Created vocabulary
# [2024-10-19 19:39:55,309] [INFO] Finished initializing nlp object
# [2024-10-19 19:39:55,753] [DEBUG] [W033] Training a new parser or NER using a model with no lexeme normalization table. This may degrade the performance of the model to some degree. If this is intentional or the language you're using doesn't have a normalization table, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed and load the table in your config. The languages with lexeme normalization tables are currently: cs, da, de, el, en, grc, id, lb, mk, pt, ru, sr, ta, th
#
# Load the table in your config with:
#
# [initialize.lookups]
# @misc = "spacy.LookupsDataLoader.v1"
# lang = ${nlp.lang}
# tables = ["lexeme_norm"]
#
# [2024-10-19 19:39:55,972] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# [2024-10-19 19:39:55,981] [DEBUG] Loading corpus from path: validation_data.spacy
# [2024-10-19 19:39:55,981] [DEBUG] Loading corpus from path: training_data.spacy
# [2024-10-19 19:39:55,987] [DEBUG] Removed existing output directory: model-best
# [2024-10-19 19:39:55,988] [DEBUG] Removed existing output directory: model-last
